# %% [markdown]
# # IoT GNN Colab / Demo Notebook

# %% [markdown]
# ## Env Setup
# We need to use DGL which uses torchdata that does not support Python 3.12 (Google Colab's python version). We need to create a conda style environment in colab.

# %%
# %%bash
# # Create working directory
# mkdir -p /content/micromamba
# cd /content/micromamba
#
# # Download micromamba binary
# wget -q https://micro.mamba.pm/api/micromamba/linux-64/latest -O micromamba.tar.bz2
#
# # Extract only the binary
# tar -xvjf micromamba.tar.bz2 --strip-components=1 bin/micromamba
# chmod +x micromamba
#
# # Show version to confirm success
# ./micromamba --version
# Out:
# bin/micromamba
# 2.3.3

# %%
# %%bash
# cd /content/micromamba
# ./micromamba create -y -n iot_env python=3.10
# Out:
# Transaction
#
#   Prefix: /root/.local/share/mamba/envs/iot_env
#
#   Updating specs:
#
#    - python=3.10
#
#
#   Package                Version  Build               Channel          Size
# ─────────────────────────────────────────────────────────────────────────────
#   Install:
# ─────────────────────────────────────────────────────────────────────────────
#
#   + _libgcc_mutex            0.1  conda_forge         conda-forge       3kB
#   + _openmp_mutex            4.5  2_gnu               conda-forge      24kB
#   + bzip2                  1.0.8  hda65f42_8          conda-forge     260kB
#   + ca-certificates   2025.11.12  hbd8a1cb_0          conda-forge     152kB
#   + icu                     75.1  he02047a_0          conda-forge      12MB
#   + ld_impl_linux-64        2.45  h1aa0949_0          conda-forge     754kB
#   + libexpat               2.7.1  hecca717_0          conda-forge      75kB
#   + libffi                 3.5.2  h9ec8514_0          conda-forge      58kB
#   + libgcc                15.2.0  h767d61c_7          conda-forge     823kB
#   + libgcc-ng             15.2.0  h69a702a_7          conda-forge      29kB
#   + libgomp               15.2.0  h767d61c_7          conda-forge     448kB
#   + liblzma                5.8.1  hb9d3cd8_2          conda-forge     113kB
#   + libnsl                 2.0.1  hb9d3cd8_1          conda-forge      34kB
#   + libsqlite             3.51.0  hee844dc_0          conda-forge     946kB
#   + libstdcxx             15.2.0  h8f9b012_7          conda-forge       4MB
#   + libstdcxx-ng          15.2.0  h4852527_7          conda-forge      29kB
#   + libuuid               2.41.2  he9a06e4_0          conda-forge      37kB
#   + libxcrypt             4.4.36  hd590300_1          conda-forge     100kB
#   + libzlib                1.3.1  hb9d3cd8_2          conda-forge      61kB
#   + ncurses                  6.5  h2d0b736_3          conda-forge     892kB
#   + openssl                3.6.0  h26f9b46_0          conda-forge       3MB
#   + pip                     25.3  pyh8b19718_0        conda-forge       1MB
#   + python               3.10.19  h3c07f61_2_cpython  conda-forge      25MB
#   + readline                 8.2  h8c095d6_2          conda-forge     282kB
#   + setuptools            80.9.0  pyhff2d567_0        conda-forge     749kB
#   + tk                    8.6.13  noxft_ha0e22de_103  conda-forge       3MB
#   + tzdata                 2025b  h78e105d_0          conda-forge     123kB
#   + wheel                 0.45.1  pyhd8ed1ab_1        conda-forge      63kB
#   + zstd                   1.5.7  hb8e6e7a_2          conda-forge     568kB
#
#   Summary:
#
#   Install: 29 packages
#
#   Total download: 56MB
#
# ─────────────────────────────────────────────────────────────────────────────
#
#
#
# Transaction starting
# Linking tzdata-2025b-h78e105d_0
# Linking ca-certificates-2025.11.12-hbd8a1cb_0
# Linking libgomp-15.2.0-h767d61c_7
# Linking _libgcc_mutex-0.1-conda_forge
# Linking _openmp_mutex-4.5-2_gnu
# Linking libgcc-15.2.0-h767d61c_7
# Linking libstdcxx-15.2.0-h8f9b012_7
# Linking openssl-3.6.0-h26f9b46_0
# Linking ncurses-6.5-h2d0b736_3
# Linking libzlib-1.3.1-hb9d3cd8_2
# Linking libgcc-ng-15.2.0-h69a702a_7
# Linking libnsl-2.0.1-hb9d3cd8_1
# Linking liblzma-5.8.1-hb9d3cd8_2
# Linking libffi-3.5.2-h9ec8514_0
# Linking bzip2-1.0.8-hda65f42_8
# Linking libuuid-2.41.2-he9a06e4_0
# Linking libexpat-2.7.1-hecca717_0
# Linking libstdcxx-ng-15.2.0-h4852527_7
# Linking readline-8.2-h8c095d6_2
# Linking zstd-1.5.7-hb8e6e7a_2
# Linking tk-8.6.13-noxft_ha0e22de_103
# Linking libxcrypt-4.4.36-hd590300_1
# Linking icu-75.1-he02047a_0
# Linking ld_impl_linux-64-2.45-h1aa0949_0
# Linking libsqlite-3.51.0-hee844dc_0
# Linking python-3.10.19-h3c07f61_2_cpython
# Linking wheel-0.45.1-pyhd8ed1ab_1
# Linking setuptools-80.9.0-pyhff2d567_0
# Linking pip-25.3-pyh8b19718_0
#
# Transaction finished
#
#
# To activate this environment, use:
#
#     micromamba activate iot_env
#
# Or to execute a single command in this environment, use:
#
#     micromamba run -n iot_env mycommand

# %%
# GPU Runtime
# %%bash
cd /content/micromamba

# Upgrade installer
./micromamba run -n iot_env pip install --upgrade pip wheel

# Install GPU PyTorch (CUDA 12.1 compatible driver)
./micromamba run -n iot_env pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121

# Install DGL GPU build
./micromamba run -n iot_env pip install dgl-cu121==1.1.2 -f https://data.dgl.ai/wheels/cu121/repo.html

# Common dependencies
./micromamba run -n iot_env pip install numpy pandas scikit-learn matplotlib networkx
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     210         try:
# --> 211             out, err = p.communicate(cell)
#     212         except KeyboardInterrupt:
#
# /usr/lib/python3.12/subprocess.py in communicate(self, input, timeout)
#    1208             try:
# -> 1209                 stdout, stderr = self._communicate(input, endtime, timeout)
#    1210             except KeyboardInterrupt:
#
# /usr/lib/python3.12/subprocess.py in _communicate(self, input, endtime, orig_timeout)
#    2114
# -> 2115                     ready = selector.select(timeout)
#    2116                     self._check_timeout(endtime, orig_timeout, stdout, stderr)
#
# /usr/lib/python3.12/selectors.py in select(self, timeout)
#     414         try:
# --> 415             fd_event_list = self._selector.poll(timeout)
#     416         except InterruptedError:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2839787108.py in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('bash', '', 'cd /content/micromamba\n\n# Upgrade installer\n./micromamba run -n iot_env pip install --upgrade pip wheel\n\n# Install GPU PyTorch (CUDA 12.1 compatible driver)\n./micromamba run -n iot_env pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121\n\n# Install DGL GPU build\n./micromamba run -n iot_env pip install dgl-cu121==1.1.2 -f https://data.dgl.ai/wheels/cu121/repo.html\n\n# Common dependencies\n./micromamba run -n iot_env pip install numpy pandas scikit-learn matplotlib networkx\n')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     274     if line and not cell:
#     275       cell = ' '
# --> 276     return super().run_cell_magic(magic_name, line, cell)
#     277
#     278
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/magics/script.py in named_script_magic(line, cell)
#     140             else:
#     141                 line = script
# --> 142             return self.shebang(line, cell)
#     143
#     144         # write a basic docstring:
#
# <decorator-gen-103> in shebang(self, line, cell)
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     213             try:
#     214                 p.send_signal(signal.SIGINT)
# --> 215                 time.sleep(0.1)
#     216                 if p.poll() is not None:
#     217                     print("Process is interrupted.")
#
# KeyboardInterrupt:

# %%
# CPU Runtime
# %%bash
cd /content/micromamba

# Upgrade installer
./micromamba run -n iot_env pip install --upgrade pip wheel

# Install GPU PyTorch (CUDA 12.1 compatible driver)
./micromamba run -n iot_env pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121

# Install DGL GPU build
./micromamba run -n iot_env pip install dgl==1.1.2

# Common dependencies
./micromamba run -n iot_env pip install numpy pandas scikit-learn matplotlib networkx
# Out:
# Requirement already satisfied: pip in /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages (25.3)
# Requirement already satisfied: wheel in /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages (0.45.1)
# Looking in indexes: https://download.pytorch.org/whl/cu121
# Collecting torch
#   Using cached https://download.pytorch.org/whl/cu121/torch-2.5.1%2Bcu121-cp310-cp310-linux_x86_64.whl (780.4 MB)
# Collecting torchvision
#   Using cached https://download.pytorch.org/whl/cu121/torchvision-0.20.1%2Bcu121-cp310-cp310-linux_x86_64.whl (7.3 MB)
# Collecting torchaudio
#   Using cached https://download.pytorch.org/whl/cu121/torchaudio-2.5.1%2Bcu121-cp310-cp310-linux_x86_64.whl (3.4 MB)
# Collecting filelock (from torch)
#   Using cached https://download.pytorch.org/whl/filelock-3.19.1-py3-none-any.whl.metadata (2.1 kB)
# Collecting typing-extensions>=4.8.0 (from torch)
#   Using cached https://download.pytorch.org/whl/typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: networkx in /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages (from torch) (3.4.2)
# Collecting jinja2 (from torch)
#   Using cached https://download.pytorch.org/whl/jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec (from torch)
#   Using cached https://download.pytorch.org/whl/fsspec-2025.9.0-py3-none-any.whl.metadata (10 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch)
#   Using cached https://download.pytorch.org/whl/cu121/nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch)
#   Using cached https://download.pytorch.org/whl/cu121/nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch)
#   Using cached https://download.pytorch.org/whl/cu121/nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 15.4 MB/s  0:00:27
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 51.2 MB/s  0:00:05
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 68.4 MB/s  0:00:01
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 75.9 MB/s  0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 67.3 MB/s  0:00:01
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 32.4 MB/s  0:00:06
# Collecting nvidia-nccl-cu12==2.21.5 (from torch)
#   Downloading https://download.pytorch.org/whl/nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 40.5 MB/s  0:00:04
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch)
#   Downloading https://download.pytorch.org/whl/cu121/nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Collecting triton==3.1.0 (from torch)
#   Downloading https://download.pytorch.org/whl/triton-3.1.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (209.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.5/209.5 MB 70.6 MB/s  0:00:02
# Collecting sympy==1.13.1 (from torch)
#   Downloading https://download.pytorch.org/whl/sympy-1.13.1-py3-none-any.whl (6.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 105.2 MB/s  0:00:00
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch)
#   Downloading https://download.pytorch.org/whl/nvidia_nvjitlink_cu12-12.9.86-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch)
#   Downloading https://download.pytorch.org/whl/mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 20.2 MB/s  0:00:00
# Requirement already satisfied: numpy in /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages (from torchvision) (2.2.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages (from torchvision) (12.0.0)
# Collecting MarkupSafe>=2.0 (from jinja2->torch)
#   Downloading https://download.pytorch.org/whl/MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Downloading https://download.pytorch.org/whl/typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Downloading https://download.pytorch.org/whl/filelock-3.19.1-py3-none-any.whl (15 kB)
# Downloading https://download.pytorch.org/whl/fsspec-2025.9.0-py3-none-any.whl (199 kB)
# Downloading https://download.pytorch.org/whl/jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading https://download.pytorch.org/whl/nvidia_nvjitlink_cu12-12.9.86-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.7/39.7 MB 51.9 MB/s  0:00:00
# Installing collected packages: mpmath, typing-extensions, sympy, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, MarkupSafe, fsspec, filelock, triton, nvidia-cusparse-cu12, nvidia-cudnn-cu12, jinja2, nvidia-cusolver-cu12, torch, torchvision, torchaudio
#
# Successfully installed MarkupSafe-2.1.5 filelock-3.19.1 fsspec-2025.9.0 jinja2-3.1.6 mpmath-1.3.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.9.86 nvidia-nvtx-cu12-12.1.105 sympy-1.13.1 torch-2.5.1+cu121 torchaudio-2.5.1+cu121 torchvision-0.20.1+cu121 triton-3.1.0 typing-extensions-4.15.0
# Collecting dgl==1.1.2
#   Downloading dgl-1.1.2-cp310-cp310-manylinux1_x86_64.whl.metadata (557 bytes)
# Requirement already satisfied: numpy>=1.14.0 in /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages (from dgl==1.1.2) (2.2.6)
# Requirement already satisfied: scipy>=1.1.0 in /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages (from dgl==1.1.2) (1.15.3)
# Requirement already satisfied: networkx>=2.1 in /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages (from dgl==1.1.2) (3.4.2)
# Collecting requests>=2.19.0 (from dgl==1.1.2)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting tqdm (from dgl==1.1.2)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting psutil>=5.8.0 (from dgl==1.1.2)
#   Downloading psutil-7.1.3-cp36-abi3-manylinux2010_x86_64.manylinux_2_12_x86_64.manylinux_2_28_x86_64.whl.metadata (23 kB)
# Collecting charset_normalizer<4,>=2 (from requests>=2.19.0->dgl==1.1.2)
#   Downloading charset_normalizer-3.4.4-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (37 kB)
# Collecting idna<4,>=2.5 (from requests>=2.19.0->dgl==1.1.2)
#   Downloading idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.19.0->dgl==1.1.2)
#   Downloading urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.19.0->dgl==1.1.2)
#   Downloading certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# Downloading dgl-1.1.2-cp310-cp310-manylinux1_x86_64.whl (6.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 3.6 MB/s  0:00:01
# Downloading psutil-7.1.3-cp36-abi3-manylinux2010_x86_64.manylinux_2_12_x86_64.manylinux_2_28_x86_64.whl (263 kB)
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.4-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (153 kB)
# Downloading idna-3.11-py3-none-any.whl (71 kB)
# Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
# Downloading certifi-2025.11.12-py3-none-any.whl (159 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: urllib3, tqdm, psutil, idna, charset_normalizer, certifi, requests, dgl
#
# Successfully installed certifi-2025.11.12 charset_normalizer-3.4.4 dgl-1.1.2 idna-3.11 psutil-7.1.3 requests-2.32.5 tqdm-4.67.1 urllib3-2.5.0
# Requirement already satisfied: numpy in /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages (2.2.6)
# Requirement already satisfied: pandas in /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages (2.3.3)
# Requirement already satisfied: scikit-learn in /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages (1.7.2)
# Requirement already satisfied: matplotlib in /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages (3.10.7)
# Requirement already satisfied: networkx in /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages (3.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.8.0 in /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: six>=1.5 in /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# %%bash
# cd /content/micromamba
#
# # Make sure pip inside env is up to date
# ./micromamba run -n iot_env pip install --upgrade pip wheel
#
# # Install PyTorch Geometric (CPU build)
# ./micromamba run -n iot_env pip install torch-geometric
#
# # Install additional required PyG ops (CPU wheels)
# ./micromamba run -n iot_env pip install pyg-lib torch-scatter torch-sparse torch-cluster torch-spline-conv -f https://data.pyg.org/whl/torch-2.1.0+cpu.html
# Out:
# Requirement already satisfied: pip in /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages (25.3)
# Requirement already satisfied: wheel in /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages (0.45.1)
# Collecting torch-geometric
#   Using cached torch_geometric-2.7.0-py3-none-any.whl.metadata (63 kB)
# Collecting aiohttp (from torch-geometric)
#   Downloading aiohttp-3.13.2-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (8.1 kB)
# Requirement already satisfied: fsspec in /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages (from torch-geometric) (2025.9.0)
# Requirement already satisfied: jinja2 in /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages (from torch-geometric) (3.1.6)
# Requirement already satisfied: numpy in /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages (from torch-geometric) (2.2.6)
# Requirement already satisfied: psutil>=5.8.0 in /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages (from torch-geometric) (7.1.3)
# Requirement already satisfied: pyparsing in /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages (from torch-geometric) (3.2.5)
# Requirement already satisfied: requests in /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages (from torch-geometric) (2.32.5)
# Requirement already satisfied: tqdm in /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages (from torch-geometric) (4.67.1)
# Collecting xxhash (from torch-geometric)
#   Downloading xxhash-3.6.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp->torch-geometric)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp->torch-geometric)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting async-timeout<6.0,>=4.0 (from aiohttp->torch-geometric)
#   Downloading async_timeout-5.0.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting attrs>=17.3.0 (from aiohttp->torch-geometric)
#   Downloading attrs-25.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp->torch-geometric)
#   Downloading frozenlist-1.8.0-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (20 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->torch-geometric)
#   Downloading multidict-6.7.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp->torch-geometric)
#   Downloading propcache-0.4.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp->torch-geometric)
#   Downloading yarl-1.22.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (75 kB)
# Requirement already satisfied: typing-extensions>=4.1.0 in /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages (from multidict<7.0,>=4.5->aiohttp->torch-geometric) (4.15.0)
# Requirement already satisfied: idna>=2.0 in /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages (from yarl<2.0,>=1.17.0->aiohttp->torch-geometric) (3.11)
# Requirement already satisfied: MarkupSafe>=2.0 in /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages (from jinja2->torch-geometric) (2.1.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages (from requests->torch-geometric) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages (from requests->torch-geometric) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages (from requests->torch-geometric) (2025.11.12)
# Downloading torch_geometric-2.7.0-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 17.7 MB/s  0:00:00
# Downloading aiohttp-3.13.2-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 12.6 MB/s  0:00:00
# Downloading async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Downloading multidict-6.7.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (241 kB)
# Downloading yarl-1.22.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (346 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading attrs-25.4.0-py3-none-any.whl (67 kB)
# Downloading frozenlist-1.8.0-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (219 kB)
# Downloading propcache-0.4.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (196 kB)
# Downloading xxhash-3.6.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (193 kB)
# Installing collected packages: xxhash, propcache, multidict, frozenlist, attrs, async-timeout, aiohappyeyeballs, yarl, aiosignal, aiohttp, torch-geometric
#
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.13.2 aiosignal-1.4.0 async-timeout-5.0.1 attrs-25.4.0 frozenlist-1.8.0 multidict-6.7.0 propcache-0.4.1 torch-geometric-2.7.0 xxhash-3.6.0 yarl-1.22.0
# Looking in links: https://data.pyg.org/whl/torch-2.1.0+cpu.html
# Collecting pyg-lib
#   Downloading https://data.pyg.org/whl/torch-2.1.0%2Bcpu/pyg_lib-0.4.0%2Bpt21cpu-cp310-cp310-linux_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 45.8 MB/s  0:00:00
# Collecting torch-scatter
#   Downloading https://data.pyg.org/whl/torch-2.1.0%2Bcpu/torch_scatter-2.1.2%2Bpt21cpu-cp310-cp310-linux_x86_64.whl (497 kB)
# Collecting torch-sparse
#   Downloading https://data.pyg.org/whl/torch-2.1.0%2Bcpu/torch_sparse-0.6.18%2Bpt21cpu-cp310-cp310-linux_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 33.3 MB/s  0:00:00
# Collecting torch-cluster
#   Downloading https://data.pyg.org/whl/torch-2.1.0%2Bcpu/torch_cluster-1.6.3%2Bpt21cpu-cp310-cp310-linux_x86_64.whl (745 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 745.7/745.7 kB 31.8 MB/s  0:00:00
# Collecting torch-spline-conv
#   Downloading https://data.pyg.org/whl/torch-2.1.0%2Bcpu/torch_spline_conv-1.2.2%2Bpt21cpu-cp310-cp310-linux_x86_64.whl (208 kB)
# Requirement already satisfied: scipy in /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages (from torch-sparse) (1.15.3)
# Requirement already satisfied: numpy<2.5,>=1.23.5 in /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages (from scipy->torch-sparse) (2.2.6)
# Installing collected packages: torch-spline-conv, torch-scatter, pyg-lib, torch-sparse, torch-cluster
#
# Successfully installed pyg-lib-0.4.0+pt21cpu torch-cluster-1.6.3+pt21cpu torch-scatter-2.1.2+pt21cpu torch-sparse-0.6.18+pt21cpu torch-spline-conv-1.2.2+pt21cpu

# %%
# %%bash
# cd /content/micromamba
# ./micromamba run -n iot_env python /content/IoT_GNN/e_graphsage.py
# Out:
# /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages/torch_geometric/__init__.py:4: UserWarning: An issue occurred while importing 'pyg-lib'. Disabling its usage. Stacktrace: /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages/libpyg.so: undefined symbol: _ZN2at4_ops10zeros_like4callERKNS_6TensorEN3c108optionalINS5_10ScalarTypeEEENS6_INS5_6LayoutEEENS6_INS5_6DeviceEEENS6_IbEENS6_INS5_12MemoryFormatEEE
#   import torch_geometric.typing
# /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages/torch_geometric/__init__.py:4: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages/torch_scatter/_version_cpu.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev
#   import torch_geometric.typing
# /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages/torch_geometric/__init__.py:4: UserWarning: An issue occurred while importing 'torch-cluster'. Disabling its usage. Stacktrace: /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages/torch_cluster/_version_cpu.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev
#   import torch_geometric.typing
# /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages/torch_geometric/__init__.py:4: UserWarning: An issue occurred while importing 'torch-spline-conv'. Disabling its usage. Stacktrace: /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages/torch_spline_conv/_version_cpu.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev
#   import torch_geometric.typing
# /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages/torch_geometric/__init__.py:4: UserWarning: An issue occurred while importing 'torch-sparse'. Disabling its usage. Stacktrace: /root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages/torch_sparse/_version_cpu.so: undefined symbol: _ZN3c1017RegisterOperatorsD1Ev
#   import torch_geometric.typing
# Traceback (most recent call last):
#   File "/content/IoT_GNN/e_graphsage.py", line 1, in <module>
#     from configuration import *
#   File "/content/IoT_GNN/configuration.py", line 8, in <module>
#     import matplotlib.pyplot as plt
#   File "/root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages/matplotlib/__init__.py", line 1299, in <module>
#     rcParams['backend'] = os.environ.get('MPLBACKEND')
#   File "/root/.local/share/mamba/envs/iot_env/lib/python3.10/site-packages/matplotlib/__init__.py", line 774, in __setitem__
#     raise ValueError(f"Key {key}: {ve}") from None
# ValueError: Key backend: 'module://matplotlib_inline.backend_inline' is not a valid value for backend; supported values are ['gtk3agg', 'gtk3cairo', 'gtk4agg', 'gtk4cairo', 'macosx', 'nbagg', 'notebook', 'qtagg', 'qtcairo', 'qt5agg', 'qt5cairo', 'tkagg', 'tkcairo', 'webagg', 'wx', 'wxagg', 'wxcairo', 'agg', 'cairo', 'pdf', 'pgf', 'ps', 'svg', 'template']
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /tmp/ipython-input-1889929428.py in <cell line: 0>()
# ----> 1 get_ipython().run_cell_magic('bash', '', 'cd /content/micromamba\n./micromamba run -n iot_env python /content/IoT_GNN/e_graphsage.py\n')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_shell.py in run_cell_magic(self, magic_name, line, cell)
#     274     if line and not cell:
#     275       cell = ' '
# --> 276     return super().run_cell_magic(magic_name, line, cell)
#     277
#     278
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2471             with self.builtin_trap:
#    2472                 args = (magic_arg_s, cell)
# -> 2473                 result = fn(*args, **kwargs)
#    2474             return result
#    2475
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/magics/script.py in named_script_magic(line, cell)
#     140             else:
#     141                 line = script
# --> 142             return self.shebang(line, cell)
#     143
#     144         # write a basic docstring:
#
# <decorator-gen-103> in shebang(self, line, cell)
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'cd /content/micromamba\n./micromamba run -n iot_env python /content/IoT_GNN/e_graphsage.py\n'' returned non-zero exit status 1.
