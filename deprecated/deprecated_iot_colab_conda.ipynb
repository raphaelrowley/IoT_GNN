# %% [markdown]
# # IoT GNN Colab / Demo Notebook

# %% [markdown]
# With Colab, to access other GitHub files, we first need to clone the repo.
# Create a personal access token for the GitHub repo, make sure to give it "Contents" permission in order to clone.

# %%
# Get PAT Token.
from getpass import getpass
token = getpass('Enter your GitHub token: ')

# %%
# Get Implementation Files
# !git clone https://{token}@github.com/raphaelrowley/IoT_GNN.git

# %%
# If need to reclone, do this first.
# !rm -r IoT_GNN

# %%
# Upload Dataset Files
# Download the dataset files from:
# https://drive.google.com/drive/folders/14t41P09gXTsCqPx3YFN1Pruwb2eZQrkT?usp=share_link
from google.colab import files
uploaded = files.upload()

# %% [markdown]
# **Note:** move the dataset file into a folder called data in the Colab Files tab.

# %%
# Add our files to path/
import sys
sys.path.append('/content/IoT_GNN')
sys.path.append('/content/data')

# %% [markdown]
# ## Env Setup
# We need to use DGL which uses torchdata that does not support Python 3.12 (Google Colab's python version). We need to create a conda style environment in colab.
