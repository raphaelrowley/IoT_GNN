# %% [markdown]
# # IoT GNN Kaggle / Demo Notebook

# %%
import sys
print(sys.version)
# Out:
# 3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]

# %%
# Assuming your GitHub PAT is setup and added to Kaggle account.
# See: https://www.kaggle.com/discussions/questions-and-answers/537365
from kaggle_secrets import UserSecretsClient
